# %% [markdown]
# ## 4th Class

# %%
# Operator Pricendance (PEMDAS)
    # Iska Kam yea hota hai kay bhot se operators main se decide krta hai kay pehle konsa solve krega

# PEMDAS

    # P = Parenthesis ()
    # E = Exponands (**)
    # M = Multiply (*)
    # D = Divide (//)
    # A = Addation (+)
    # S = Subtraction (-)

# %%
12*9-18+(9+3)+90
# Out:
# 192

# %%
# Data Type
    # String(str)

# %%
print("junaid".upper()) # Is se sare Case Words upper hojyange
Name= "HAMID"
print(Name.lower()) # is se sare words Lower hojyange
course="AI & Data Science"
print(course)
print(course.strip())
course.count("")
len(course)
print(Name.capitalize())
# Out:
# JUNAID
# hamid
# AI & Data Science
# AI & Data Science
# Hamid
