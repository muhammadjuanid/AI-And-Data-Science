# %% [markdown]
# # Todays Learn Topic
#  - print
#  - operators
#  - data type

# %% [markdown]
# ## print
#
# - print is a built-in python function, that print any valid value given to it. ( Value = Argument)
# - Print is also print any values comma seperator.
# - print is also working with no value or argument.
#
# ### Value or argument
# - value or argument have different types
#       - Text (string)
#       - number (int)
#       - situation (boolean)

# %%
print ("I am double quoted single line")
print ('I am single quoted single line')

print ("""I am double quoted multi line""")
print ('''I am single quoted
single line''')
# Out:
# I am double quoted single line
# I am single quoted single line
# I am double quoted multi line
# I am single quoted
# single line

# %%
print("Hello python" , end="")
print("end by dafult line change krta hai agar hum isko empty kr dain to line change nahi hogi")
# Out:
# Hello pythonend by dafult line change krta hai agar hum isko empty kr dain to line change nahi hogi
