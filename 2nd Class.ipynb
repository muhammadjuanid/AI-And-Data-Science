# %% [markdown]
# ## 2nd Class

# %% [markdown]
# #### Type

# %%
print ("hello pythan
# Out:
# hello pythan

# %%
# print = Contral + ?/

# %%
print(type("Hello World"))
# Out:
# <class 'str'>

# %%
print(type("123"))
# Out:
# <class 'str'>

# %%
# Interger

# %%
print(type("9"))
# Out:
# <class 'str'>

# %%
# Float

# %%
print(type(1.2))
# Out:
# <class 'float'>

# %%
# Boolen

# %%
print(2>6)
# Out:
# False

# %%
print(type(2>6))
# Out:
# <class 'bool'>

# %%
# Single quote

# %%
print('Junaid')
print("Hamid")
# Out:
# Junaid
# Hamid

# %%
print("""junaid
Hamid""")
# Out:
# junaid
# Hamid

# %%
print("hello",'world')
# Out:
# hello world

# %%
# \n move to the next line

# %%
print("hello\n","Junaid")
# Out:
# hello
#  Junaid

# %%
print("Junaid\n","Hamid\n","Karachi\n")
# Out:
# Junaid
#  Hamid
#  Karachi

# %%
print("Junaid\n""Hamid\n""Karachi\n")
# Out:
# Junaid
# Hamid
# Karachi

# %%
print("Hello","World", 90)
# Out:
# Hello World 90

# %%
# shift + tab -> function

# %%
print("python","world",sep="\t")
print("python","world",sep="$$$$")
print("python","world",sep="*****")
# Out:
# python	world
# python$$$$world
# python*****world

# %%
print("hello","world",9,2.5,True,sep=" - ")
# Out:
# hello - world - 9 - 2.5 - True

# %%
print("""Junaid
Hamoid""")
# Out:
# Junaid
# Hamoid

# %%
print("Name:\n'Junaid'.9")
# Out:
# Name:
# 'Junaid'.9
