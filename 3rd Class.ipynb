# %% [markdown]
# ### 3rd Class

# %%
# Variable
 # Contaioners For Store Data

# %%
Course = "AI & Data Science"

# Course = Variable
# = means Assign
#  AI & Data Science = Value

# %%
marks = 50

# %%
print("For",Course,"minimum marks","=",marks)
# Out:
# For AI & Data Science minimum marks = 50

# %%
# legal or Illegelal variables
        # Vaiables ko Number se start nahi kr sakte like 23Passenger = "Junaid" >>>> Yea Error ayega
        # Vaiable main Space Allowed nahi hai like First Name = "Junaid Hamid" >>>> Yea Error ayega
        # Special Character use nahi kr sakte like (@,#,$,%) isko bhi variable main use nahi kr sakte
        # Variables main Float yani Decimile no bhi use nahi kr sakte
        # reserved words bhi hum use nahi kr sakte reserved words wo hote hai jo system main out reserved hote hain like "True,False"

# %%
passenger1st = "Usman"
print(passenger1st)
# Out:
# Usman

# %%
first_name = "Hamza"

# %%
false = "True"

# %% [markdown]
# ![image.png](attachment:47011d8d-a505-4cb0-9272-69f7c84db06f.png)![image.png](attachment:cbe8b9c8-8576-49cd-a9fd-76bfddcfcec0.png)

# %%
# operators

    # Arithmethic operators
        # Addation (+)
        # subraction (-)
        # multliplication (*)
        # exponands (**)
        # division two types
                # float division (/)
                # florr division (//)
        # modulues (%)

    # Relational/Compression operators
        # double Equal to (==)
        # Not Equal to(!=)
        # Greator Then(>)
        # Less Then(<)
        # Greator then equal to (>=)
        # less then equalto(<=)

    # logicial operators
        # Logical and
        # Logicial Or
        # logicial Not

    # Operator precendence is ka matlab ka kis sign main periorty kisko deni hai solve krne main
        # pemdas

    # Incremenr or Decerement operators

# %%
100+300 #addation
# Out:
# 400

# %%
100-300 #subscrabtion
# Out:
# -200

# %%
400//3 #Florr Division
# Out:
# 133

# %%
400/3 #Float Division
# Out:
# 133.33333333333334

# %%
2%5
# modlues humain remaing return main deta hai
# Out:
# 2

# %%
5%8
# Out:
# 5

# %%
2**3  
# like 2*2*2
# Out:
# 8

# %%
5**7
# like (5*5*5*5*5*5*5)
# Out:
# 78125

# %%
12%4
# Out:
# 0

# %%
100>200 # return in boolesn ans is True
# Out:
# False

# %%
20<6
# Out:
# False

# %%
900 == 700 #Double equal to ans is False
700 == 700 # Double equal to ans is True
# Out:
# True

# %%
print(900 == 700) #Double equal to ans is False
print(700 == 700) # Double equal to ans is True
# Out:
# False
# True

# %%
400 != 300 # Not Equal to ans is True
400 != 400 # Not Equal to ans is False
# Out:
# False

# %%
200>=200 # Greator then equal to ans is True
200>=201 # Greator then equal to ans is False
# Out:
# False

# %%
200<=150 # less then equal to ans is False
200<=201 # less then equal to ans is True
# Out:
# True

# %% [markdown]
# #### logicial operator

# %%
# more then one condition we can use logicial operators
    # AND
    # OR
    # NOT

# %%
# OR Operator jis bhi condition main use krange agar us condition main ek bhi condintion True hogai to wo true krdega
    # like (True + False = True) ans True dene ki wja yea hai kay ek condition True hai

    # True (Or) True = True
    # True (or) False = True
    # False (or) True = True
    # False (or) False = False

# %%
A = 10
B = 20
C = 30

# %%
(A>B) or (B>C) or (C>A)
# F         F       T
# Out:
# True

# %%
# And Operator agar condition main ek bat bhai galat yani False hogai to wo puri situation ko False krdega

    # True and True = True
    # False and False = False
    # True and False = False
    # False and True = False

# %%
(A>B) and (B>C) and (C>A)
# F         F       T
# Out:
# False

# %%
# Ek statement main agar ek se ziada variable main value dalni hai to
A = B = C = 50

# %%
print(A)
print(B)
print(C)
# Out:
# 50
# 50
# 50

# %%
# Agar ek hei statement main variables main alag alag value put krni ho to
x,y,z = "junaid","hamid","ahmed"

# %%
print(x)
print(y)
print(z)
# Out:
# junaid
# hamid
# ahmed
