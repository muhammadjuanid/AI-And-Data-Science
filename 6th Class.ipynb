# %% [markdown]
# #### 6th Class

# %% [markdown]
# ### Conditional Formating
#
#     - IF Statement/if Clause (if is a Keyword         :           Statement is a condition)

# %%
a = 10
if a > 5:
    print("A is greator then 5")
# Out:
# A is greator then 5

# %%
battery = int(input("Enter your number"))
if battery > 10:
    print("Reals Dakho")
elif battery == 10:
    print("Charge pe lga kay dakho")
else:
    print("Charge kro")
# Out:
# Enter your number 10
# Charge pe lga kay dakho
