# %% [markdown]
# ## 5th Class

# %%
course = "ai and data science"

# %%
print(course.find("d")) # yea to simple hai kay D word hamare string main 5th number pe hai
print(course.find("d" , 6)) # is case main humne isko yea bola hai kay D ko find kro lekin finding start 6th word se krna
# Out:
# 5
# 7

# %%
print(course.endswith("C")) # Is main string ka last word dakhega kay agar wo C hai to True warna False Ans True/False main dega
# Out:
# False

# %%
course.replace("and","&") # ab yea and ko replace krega & se lekin memory main store nahi krega
# Out:
# 'ai & data science'

# %%
course.title() # yea har word kay pehle alpha ko Capital krdega
# Out:
# 'Ai And Data Science'

# %%
" ".join(course)
Word = ["Hello","World"]
Ans = " ".join(Word)
print(Ans)
# Out:
# Hello World

# %% [markdown]
# ##### Type Casting
#
#     #Aik Data type ko dusri data type main convert krne

# %% [markdown]
# ### User Input
#
#     # Yea hamesha String main return krega

# %%
name = input("Enter Your Name:") # Yea return krega Input line jis kay zarye hum kisi user se Data get krte hain
age = input("Enter Your Age") # Same as previous
# Out:
# Enter Your Name: Muhammad Junaid Hamid
# Enter Your Age 35

# %%
print(name,"\t",age)
# Out:
# Muhammad Junaid Hamid 	 35

# %%
print(type(name)) # in dono ki types String ayegi kyu kay Input ka return hamesha String main ayega
print(type(age)) # same age agar hum number main le rhe hain to return srting main hei ayega

print(type(int(age))) # ab humne yea ek or function call kia hai tyoe Cast ka is se hum kisi bhi data type ko change kr sakte hain is kay under mene type change kr di hao or isko Interger pe convert krdia aho
# Out:
# <class 'str'>
# <class 'str'>
# <class 'int'>

# %%
name = input("Enter your name")
age = input("Enter your age")

print("Your Name is",name,",""Your age is",age)
print(f"Your name is {name}, Your age is {age}") # Is function ko F String bolte hain
# Out:
# Enter your name Junaid
# Enter your age 20
# Your Name is Junaid ,Your age is 20
# Your name is Junaid, Your age is 20

# %% [markdown]
# ##### Formate Function

# %% [markdown]
# ##### Identatity Card

# %%
name = input("Enter Your Name: ")
father_name = input("Enter Your Father Name: ")
roll_number = int(input("Enter your Roll No: "))
course = input("Enter Your Course: ")
institute_name = input("Enter your Instituted Name: ")
branch = input("Enter your Branch Name: ")

print(f"""
=========================================
            Student ID Card
=========================================

    Name       :      {name}
    Father Name:      {father_name}
    Roll No.   :      {roll_number}
    Course     :      {course}
    Instituted :      {institute_name}
    Branch     :      {branch}
    
========================================
""")
# Out:
# Enter Your Name:  Muhammad Junaid
# Enter Your Father Name:  Hamid
# Enter your Roll No:  123456
# Enter Your Course:  Ai and Data Science
# Enter your Instituted Name:  Sylani Mass It Tranning
# Enter your Branch Name:  Head Office
# ...
#             Student ID Card
# ...
#
#     Name       :      Muhammad Junaid
#     Father Name:      Hamid
#     Roll No.   :      123456
#     Course     :      Ai and Data Science
#     Instituted :      Sylani Mass It Tranning
#     Branch     :      Head Office
#
# ...
